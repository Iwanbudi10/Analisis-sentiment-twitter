# %%
import tweepy
import csv
import pandas as pd

# Masukkan Twitter Token API
consumer_key= 'FNlOpihlkjJtxvEM3mVnhGdWt'
consumer_secret= 'g7QHErToiEel0TJoBprhoN8ACWoFCqKQDomQbKqwU69z6rftTa'
access_token= '1394438716580528131-63QPZPklOCkU4Wpd2zzGQALRVg9pPS'
access_token_secret= 's6Uk0B0goNfknJNdbsYcyG75Dr60KcmzWI3dQOjKPH2Ug'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# Buat path file CSV kedalam variabel
csvFile = open('DatasetVaksin16Juli17Juli.csv', 'a')

# buat variabel baru untuk membuat file csv
csvWriter = csv.writer(csvFile)

# Mulai crawling search tweet
for tweet in tweepy.Cursor(api.search,q="vaksin OR vaksinasi -filter:retweets",lang="in",since="2022-7-16", until = "2022-7-17").items(1000):
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text])
# Out:
# 2022-07-16 23:58:19 Semoga ga demamlah, nekad banget siang vaksin malemnya perjalanan jauh haha
# 2022-07-16 23:58:07 @ariomotor Selamat pagi Kak. Saat ini tersedia layanan vaksinasi dibeberapa stasiun untuk calon penumpang KA. Guna… https://t.co/IgeV6Uet4h
# 2022-07-16 23:57:23 @sipinputra Selamat pagi kak, tersedia hari ini untuk layanan vaksin di Stasiun Manggarai hall timur, info lengkap… https://t.co/vzSHBfp7Be
# 2022-07-16 23:57:23 @KAI121 Ka.. Kalau naik kereta kamandaka apa harus antigen?? Soalnya saya baru vaksin kedua
# 2022-07-16 23:55:18 Puak gini bila suruh ambik vaksin cakap vaksin bukan dicipta oleh orang islam, tapi kenyataan dari Dr bukan islam p… https://t.co/6WpW5XIRW8
# 2022-07-16 23:54:31 @CommuterLine min, rabu/kamis depan, 20-21 Juli, ada vaksinasi covid kah, di St.Manggarai?sblah mana ya?thx min
# 2022-07-16 23:53:40 @Tuti_embeeeeer @PakuanGiri @Sheriutami @Haryono___Adi @BalonkuLim15 @StopPlandemit Sama aja dengan teori vaksin..… https://t.co/EiXQnyQiQU
# ...
